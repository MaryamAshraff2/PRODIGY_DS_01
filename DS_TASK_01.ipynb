# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files

# Upload the file (assuming you're using Google Colab for file upload)
uploaded = files.upload()

# Load the dataset into a pandas DataFrame
file_name = list(uploaded.keys())[0]
df = pd.read_csv(file_name, skiprows=4)

# Define mappings of countries to continents (simplified for example purposes)
continent_map = {
    'Aruba': 'North America',
    'Afghanistan': 'Asia',
    'Angola': 'Africa',
    'Albania': 'Europe',
    'Andorra': 'Europe',
    'United Arab Emirates': 'Asia',
    'Argentina': 'South America',
    'Armenia': 'Asia',
    'American Samoa': 'Australia/Oceania',
    'Antigua and Barbuda': 'North America',
    'Australia': 'Australia/Oceania',
    'Austria': 'Europe',
    'Azerbaijan': 'Asia',
    'Burundi': 'Africa',
    'Belgium': 'Europe',
    'Benin': 'Africa',
    'Burkina Faso': 'Africa',
    'Bangladesh': 'Asia',
    'Bulgaria': 'Europe',
    'Bahrain': 'Asia',
    'Bahamas, The': 'North America',
    'Bosnia and Herzegovina': 'Europe',
    'Belarus': 'Europe',
    'Belize': 'North America',
    'Bermuda': 'North America',
    'Bolivia': 'South America',
    'Brazil': 'South America',
    'Barbados': 'North America',
    'Brunei Darussalam': 'Asia',
    'Bhutan': 'Asia',
    'Botswana': 'Africa',
    'Central African Republic': 'Africa',
    'Canada': 'North America',
    'Switzerland': 'Europe',
    'Chile': 'South America',
    'China': 'Asia',
    'Cote d\'Ivoire': 'Africa',
    'Cameroon': 'Africa',
    'Congo, Rep.': 'Africa',
    'Colombia': 'South America',
    'Comoros': 'Africa',
    'Cabo Verde': 'Africa',
    'Costa Rica': 'North America',
    'Cuba': 'North America',
    'Curacao': 'North America',
    'Cayman Islands': 'North America',
    'Cyprus': 'Asia',
    'Czech Republic': 'Europe',
    'Germany': 'Europe',
    'Djibouti': 'Africa',
    'Dominica': 'North America',
    'Denmark': 'Europe',
    'Dominican Republic': 'North America',
    'Algeria': 'Africa',
    'Ecuador': 'South America',
    'Egypt, Arab Rep.': 'Africa',
    'Eritrea': 'Africa',
    'Spain': 'Europe',
    'Estonia': 'Europe',
    'Ethiopia': 'Africa',
    'Finland': 'Europe',
    'Fiji': 'Australia/Oceania',
    'France': 'Europe',
    'Micronesia, Fed. Sts.': 'Australia/Oceania',
    'Gabon': 'Africa',
    'United Kingdom': 'Europe',
    'Georgia': 'Asia',
    'Ghana': 'Africa',
    'Guinea': 'Africa',
    'Gambia, The': 'Africa',
    'Guinea-Bissau': 'Africa',
    'Equatorial Guinea': 'Africa',
    'Greece': 'Europe',
    'Grenada': 'North America',
    'Greenland': 'North America',
    'Guatemala': 'North America',
    'Guam': 'Australia/Oceania',
    'Guyana': 'South America',
    'Hong Kong SAR, China': 'Asia',
    'Honduras': 'North America',
    'Croatia': 'Europe',
    'Haiti': 'North America',
    'Hungary': 'Europe',
    'Indonesia': 'Asia',
    'India': 'Asia',
    'Ireland': 'Europe',
    'Iran, Islamic Rep.': 'Asia',
    'Iraq': 'Asia',
    'Iceland': 'Europe',
    'Israel': 'Asia',
    'Italy': 'Europe',
    'Jamaica': 'North America',
    'Jordan': 'Asia',
    'Japan': 'Asia',
    'Kazakhstan': 'Asia',
    'Kenya': 'Africa',
    'Kyrgyz Republic': 'Asia',
    'Cambodia': 'Asia',
    'Kiribati': 'Australia/Oceania',
    'St. Kitts and Nevis': 'North America',
    'Korea, Rep.': 'Asia',
    'Kuwait': 'Asia',
    'Lao PDR': 'Asia',
    'Lebanon': 'Asia',
    'Liberia': 'Africa',
    'Libya': 'Africa',
    'St. Lucia': 'North America',
    'Liechtenstein': 'Europe',
    'Sri Lanka': 'Asia',
    'Lesotho': 'Africa',
    'Lithuania': 'Europe',
    'Luxembourg': 'Europe',
    'Latvia': 'Europe',
    'Macao SAR, China': 'Asia',
    'St. Martin (French part)': 'North America',
    'Morocco': 'Africa',
    'Monaco': 'Europe',
    'Moldova': 'Europe',
    'Madagascar': 'Africa',
    'Maldives': 'Asia',
    'Mexico': 'North America',
    'Marshall Islands': 'Australia/Oceania',
    'North Macedonia': 'Europe',
    'Mali': 'Africa',
    'Malta': 'Europe',
    'Myanmar': 'Asia',
    'Montenegro': 'Europe',
    'Mongolia': 'Asia',
    'Northern Mariana Islands': 'Australia/Oceania',
    'Mozambique': 'Africa',
    'Mauritania': 'Africa',
    'Mauritius': 'Africa',
    'Malawi': 'Africa',
    'Malaysia': 'Asia',
    'Namibia': 'Africa',
    'New Caledonia': 'Australia/Oceania',
    'Niger': 'Africa',
    'Nigeria': 'Africa',
    'Nicaragua': 'North America',
    'Netherlands': 'Europe',
    'Norway': 'Europe',
    'Nepal': 'Asia',
    'Nauru': 'Australia/Oceania',
    'New Zealand': 'Australia/Oceania',
    'Oman': 'Asia',
    'Pakistan': 'Asia',
    'Panama': 'North America',
    'Peru': 'South America',
    'Philippines': 'Asia',
    'Palau': 'Australia/Oceania',
    'Papua New Guinea': 'Australia/Oceania',
    'Poland': 'Europe',
    'Puerto Rico': 'North America',
    'Portugal': 'Europe',
    'Paraguay': 'South America',
    'West Bank and Gaza': 'Asia',
    'French Polynesia': 'Australia/Oceania',
    'Qatar': 'Asia',
    'Romania': 'Europe',
    'Russian Federation': 'Europe',
    'Rwanda': 'Africa',
    'Saudi Arabia': 'Asia',
    'Sudan': 'Africa',
    'Senegal': 'Africa',
    'Singapore': 'Asia',
    'Solomon Islands': 'Australia/Oceania',
    'Sierra Leone': 'Africa',
    'El Salvador': 'North America',
    'San Marino': 'Europe',
    'Somalia': 'Africa',
    'Serbia': 'Europe',
    'South Sudan': 'Africa',
    'Sao Tome and Principe': 'Africa',
    'Suriname': 'South America',
    'Slovak Republic': 'Europe',
    'Slovenia': 'Europe',
    'Sweden': 'Europe',
    'Eswatini': 'Africa',
    'Seychelles': 'Africa',
    'Syrian Arab Republic': 'Asia',
    'Turks and Caicos Islands': 'North America',
    'Chad': 'Africa',
    'Togo': 'Africa',
    'Thailand': 'Asia',
    'Tajikistan': 'Asia',
    'Turkmenistan': 'Asia',
    'Timor-Leste': 'Asia',
    'Tonga': 'Australia/Oceania',
    'Trinidad and Tobago': 'North America',
    'Tunisia': 'Africa',
    'Turkey': 'Asia',
    'Tuvalu': 'Australia/Oceania',
    'Tanzania': 'Africa',
    'Uganda': 'Africa',
    'Ukraine': 'Europe',
    'Uruguay': 'South America',
    'United States': 'North America',
    'Uzbekistan': 'Asia',
    'St. Vincent and the Grenadines': 'North America',
    'Venezuela, RB': 'South America',
    'British Virgin Islands': 'North America',
    'Virgin Islands (U.S.)': 'North America',
    'Vietnam': 'Asia',
    'Vanuatu': 'Australia/Oceania',
    'Samoa': 'Australia/Oceania',
    'Kosovo': 'Europe',
    'Yemen, Rep.': 'Asia',
    'South Africa': 'Africa',
    'Zambia': 'Africa',
    'Zimbabwe': 'Africa'
}

# Add a new column 'Continent' based on the mappings
df['Continent'] = df['Country Name'].map(continent_map)

# Define the list of all continents
continents = ['Asia', 'Africa', 'North America', 'South America', 'Antarctica', 'Europe', 'Australia/Oceania']

# Aggregate population data by continent
df_continent = df.groupby('Continent')[['1970', '1980', '1990', '2000', '2010', '2020']].sum()

# Ensure all continents are included, even if some have no data
df_continent = df_continent.reindex(continents)

# Plotting a bar chart for population data by continent
plt.figure(figsize=(12, 8))
ax = df_continent.transpose().plot(kind='bar', stacked=False)
plt.title('Population by Continent (1970-2020)')
plt.xlabel('Year')
plt.ylabel('Population Size')
plt.xticks(rotation=0)
plt.legend(title='Continent')

# Format y-axis ticks to display population size in millions
ax.yaxis.set_major_formatter('{:,.0f}'.format)  # Format as integer with thousands separator
plt.show()
# Out:
#      <input type="file" id="files-21efe3f7-f82c-45b9-8a5b-7af74bd2c34f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-21efe3f7-f82c-45b9-8a5b-7af74bd2c34f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
